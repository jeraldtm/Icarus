# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.xarray
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.bk-hbox {
#     display: flex;
#     justify-content: center;
# }
#
# div.bk-hbox div.bk-plot {
#     padding: 8px;
# }
#
# div.bk-hbox div.bk-data-table {
#     padding: 20px;
# }
#
# div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
# ...

# %% [markdown]
# # This is just a slightly more refined scan than what was done before

# %%
lox = 12.6
hix = 13.9
stepx = 0.03
loy = 12.3
hiy = 13.6
stepy = 0.03

# %%
xpts = np.arange(lox, hix + stepx, stepx)
ypts = np.arange(loy, hiy + stepy, stepy)

# %%
phi90 = pd.read_csv('probe_wire_side_1.55mm_shim_fieldRaster_2019-02-06_3.csv', comment='#')

# %%
phi0 = pd.read_csv('probe_wire_side_1.55mm_shim_fieldRaster_2019-02-06_4.csv', comment='#')

# %%
phi0
# Out:
#           X      Y  Xfield_avg  Yfield_avg  Zfield_avg    Xfield_std  \
# 0     12.60  12.30    0.009826    0.220096    0.068057  3.995056e-05
# 1     12.63  12.30    0.009871    0.220085    0.068074  1.443481e-05
# 2     12.66  12.30    0.009875    0.220038    0.068166  3.381042e-05
# 3     12.69  12.30    0.009793    0.220099    0.068138  1.086121e-05
# 4     12.72  12.30    0.009845    0.220078    0.068155  2.020874e-05
# 5     12.75  12.30    0.009751    0.220022    0.068224  8.322144e-06
# 6     12.78  12.30    0.009847    0.220023    0.068233  1.303711e-05
# 7     12.81  12.30    0.009790    0.220055    0.068306  2.060852e-05
# 8     12.84  12.30    0.009760    0.220006    0.068280  2.357788e-05
# 9     12.87  12.30    0.009778    0.219956    0.068382  1.837158e-05
# 10    12.90  12.30    0.009739    0.220016    0.068433  6.579590e-06
# 11    12.93  12.30    0.009781    0.219998    0.068438  1.124268e-05
# 12    12.96  12.30    0.009725    0.219980    0.068523  6.097412e-06
# ...

# %%
phi0_dv = {}
phi90_dv = {}
for c in phi0.columns[2:]:
    phi0_dv[c] = (["X", "Y"], phi0[c].values.reshape(xpts.size, ypts.size))
    phi90_dv[c] = (["X", "Y"], phi90[c].values.reshape(xpts.size, ypts.size))

# %%
coords = {'X': ('X', xpts), 'Y': ('Y', ypts)}

# %%
phi0_ds = xr.Dataset(phi0_dv, coords)
phi90_ds = xr.Dataset(phi90_dv, coords)

# %%
phi0_ds
# Out:
# <xarray.Dataset>
# Dimensions:     (X: 45, Y: 45)
# Coordinates:
#   * X           (X) float64 12.6 12.63 12.66 12.69 ... 13.83 13.86 13.89 13.92
#   * Y           (Y) float64 12.3 12.33 12.36 12.39 ... 13.53 13.56 13.59 13.62
# Data variables:
#     Xfield_avg  (X, Y) float64 0.009826 0.009871 0.009875 ... 0.01145 0.01142
#     Yfield_avg  (X, Y) float64 0.2201 0.2201 0.22 ... 0.2292 0.2291 0.2291
#     Zfield_avg  (X, Y) float64 0.06806 0.06807 0.06817 ... 0.02885 0.02888
#     Xfield_std  (X, Y) float64 3.995e-05 1.443e-05 ... 8.53e-06 4.034e-06
#     Yfield_std  (X, Y) float64 5.12e-05 6.659e-06 ... 1.385e-05 2.304e-05
#     Zfield_std  (X, Y) float64 2.578e-05 2.37e-05 ... 2.771e-05 2.422e-05

# %%
phi0_ds.Yfield_avg.hvplot()
# Out:
# :Image   [Y,X]   (Yfield_avg)

# %%
phi0_ds.Zfield_avg.hvplot()
# Out:
# :Image   [Y,X]   (Zfield_avg)

# %%
phi0_ds.Xfield_avg.hvplot()
# Out:
# :Image   [Y,X]   (Xfield_avg)

# %%
Zfield_mod = (phi90_ds.Zfield_avg**2 + phi0_ds.Zfield_avg**2)

# %%
Zfield_mod.hvplot(title = "Combined 0 and 90 Z field")
# Out:
# :Image   [Y,X]   (Zfield_avg)

# %%
Zfield_mod.where(Zfield_mod == Zfield_mod.min(), drop=True)
# Out:
# <xarray.DataArray 'Zfield_avg' (X: 1, Y: 1)>
# array([[0.001128]])
# Coordinates:
#   * X        (X) float64 13.92
#   * Y        (Y) float64 12.3

# %%
Yfield_mod = (phi90_ds.Xfield_avg**2 + phi0_ds.Yfield_avg**2)

# %%
Yfield_mod.hvplot(title="Combined 0 and 90 Y field")
# Out:
# :Image   [Y,X]   (value)

# %%
Yfield_mod.where(Yfield_mod == Yfield_mod.max(), drop=True)
# Out:
# <xarray.DataArray (X: 1, Y: 1)>
# array([[0.090482]])
# Coordinates:
#   * X        (X) float64 13.5
#   * Y        (Y) float64 12.9

# %% [markdown]
# # From these, seems like the best point is $(13.5,12.9)$ with pretty strong corroboration beetween $Y$ maximum and $Z$ minimum field strength points

# %%
Xfield_mod = (phi90_ds.Yfield_avg**2 + phi0_ds.Xfield_avg**2)
Xfield_mod.hvplot(title="Combined 0 and 90 X field")
# Out:
# :Image   [Y,X]   (value)

# %%
Xfield_mod.where(Xfield_mod == Xfield_mod.min(), drop=True)
# Out:
# <xarray.DataArray (X: 1, Y: 1)>
# array([[0.000185]])
# Coordinates:
#   * X        (X) float64 10.0
#   * Y        (Y) float64 15.05
